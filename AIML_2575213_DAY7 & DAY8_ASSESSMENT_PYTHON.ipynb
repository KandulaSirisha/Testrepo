# %% [markdown]
# # Implementation of Data Structures in Python

# %% [markdown]
# # 1. Write a Python program to find a target values in a list using linear search with following steps:
# a. Initialize the list to store the input elements.
# b. Initialize found=False.
# c. Enter the item to be searched (match_item).
# d. For each element in the list
#     1. if match_item = value
#         a. return match_item's position.
# e. If the match_item is not in the list, display an error message that the item is not found in the list.

# %%
# a.Initialize the list to store the input elements
lst = []

# b.Initialize found to False
found = False

# c.Input elements into the list
list_elements = int(input("Enter no.of elements you want in the list: "))
for i in range(list_elements):
    element = int(input("Enter element {}:".format(i+1)))
    lst.append(element)

#d. Enter the item to be searched 
match_item = int(input("Enter the element to be searched in the list: "))

# Linear search
for i, value in enumerate(lst):
    if match_item == value:
        found = True
        position = i + 1  
        break
# e. Check if the item was found or not
if found:
    print("{} found at position {}".format(match_item,position))
else:
    print("{} is not found in the list.")
# Out:
# Enter no.of elements you want in the list: 3
# Enter element 1:8
# Enter element 2:3
# Enter element 3:5
# Enter the element to be searched in the list: 3
# 3 found at position 2

# %% [markdown]
# # 2. Write a Python program to implement binary search to find the target values from the list:
# a. Create a separate function to do binary search.
# b. Get the number of inputs from the user.
# c. Store the inputs individually in a list.
# d. In binary search function at first sort the list in order to start the search from middle of the list.
# e. Compare the middle element to right and left elements to search target element.
# f. If greater, move to right of list or else move to another side of the list.
# g. Print the result along with the position of the element.

# %%
#a. Create a separate function to do binary search.
def binary_search(lst, target):
#d. In binary search function at first sort the list in order to start the search from middle of the list.
    lst.sort()
    left= 0
    right=len(lst) - 1
#e. Compare the middle element to right and left elements to search target element.
#f. If greater, move to right of list or else move to another side of the list.
    while left <= right:
        mid = left + (right - left) // 2

        if lst[mid] == target:
            return mid  # Element found, return its position
        elif lst[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return -1  # Element not found

# b.Get the number of inputs from the user
num_elements = int(input("Enter the number of elements in the list: "))

# c.Store the inputs individually in a list
input_list = []
for i in range(num_elements):
    element = int(input("Enter element {}: ".format(i + 1)))
    input_list.append(element)

# Enter the target element to be searched
target = int(input("Enter the element to be searched: "))

# Perform binary search
result = binary_search(input_list, target)
#g. Print the result along with the position of the element.
# Check if the element was found or not
if result != -1:
    print("{} found at position {}".format(target,result+1))
else:
    print("{} is not found in the list.".format(target))
# Out:
# Enter the number of elements in the list: 3
# Enter element 1: 7
# Enter element 2: 5
# Enter element 3: 8
# Enter the element to be searched: 5
# 5 found at position 1

# %% [markdown]
# # 3. Write a Python program for sorting a list of elements using selection sort algorithm:
# a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list.
# b. In the first iteration, find the smallest element in the unsorted list and place it in the sorted list.
# c. In the second iteration, find the smallest element in the unsorted list and place it in the correct position by comparing with the element in the sorted list.
# d. In the third iteration, again find the smallest element in the unsorted list and place it in the correct position by comparing with the elements in the sorted list.
# e. This process continues till the unsorted list becomes empty.
# f. Display the sorted list.

# %%
# Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list.
def selection_sort(input_list):
    sorted_list = []

    while input_list:
        # Find the smallest element in the unsorted list
        small_element = min(input_list)

        # Remove the smallest element from the unsorted list
        input_list.remove(small_element)

        # Add the smallest element to the sorted list
        sorted_list.append(small_element)

    return sorted_list

# Input list
unsorted_list = [7,4,10,8,11,1]
print("Unsorted list:",unsorted_list)

# Call the selection_sort function to sort the list
sorted_list = selection_sort(unsorted_list)

# Display the sorted list
print("Sorted list:", sorted_list)
# Out:
# Unsorted list: [7, 4, 10, 8, 11, 1]
# Sorted list: [1, 4, 7, 8, 10, 11]

# %% [markdown]
# # 4. Write a Python program for sorting a list of elements using insertion sort algorithm:
# a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list.
# b. In the first iteration, take the first element in the unsorted list and insert it in Sorted list.
# c.In the second iteration, take the second element in the given list and compare with the element in the sorted sub list and place it in the correct position. I
# d. In the third iteration, take the third element in the given list and compare with the elements in the sorted sub list and place the elements in the correct position.
# e. This process continues until the last element is inserted in the sorted sub list.
# f. Display the sorted elements.

# %%
def insertion_sort(input_list):
    for i in range(1, len(input_list)):
        key = input_list[i]  # Current element to be inserted into the sorted sublist
        j = i - 1  # Index of the last element in the sorted sublist

        # Move elements of the sorted sublist greater than key one position to the right
        while j >= 0 and key < input_list[j]:
            input_list[j + 1] = input_list[j]
            j -= 1

        # Insert the current element into the correct position in the sorted sublist
        input_list[j + 1] = key

# Input list
unsorted_list = [42, 25, 12, 27, 11]
print("Unsorted list:",unsorted_list)

# Call the insertion_sort function to sort the list
insertion_sort(unsorted_list)

# Display the sorted list
print("Sorted list:", unsorted_list)
# Out:
# Unsorted list: [42, 25, 12, 27, 11]
# Sorted list: [11, 12, 25, 27, 42]

# %% [markdown]
# # 5. Write a Python program that performs merge sort on a list of numbers:
# a. Divide: If the given array has zero or one element, return.1. Otherwise
#     ii. Divide the input list in to two halves each containing half of the elements, i.e. left half and right half.
# b. Conquer: Recursively sort the two lists (left half and right half).
#     a. Call the merge sort on left half.
#     b. Call the merge sort on right half.
# c. Combine: Combine the elements back in the input list by merging the two sorted lists into a sorted sequence.

# %%
def merge_sort(lst):
    if len(lst) > 1:
        mid = len(lst) // 2  # Find the middle of the list
        left_half = lst[:mid]  # Divide the list into two halves
        right_half = lst[mid:]

        # Recursively sort the left and right halves
        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0  # Initialize indices for merging

        # Merge the two halves back into the original list
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                lst[k] = left_half[i]
                i += 1
            else:
                lst[k] = right_half[j]
                j += 1
            k += 1

        # Check if any elements were left in either of the two halves
        while i < len(left_half):
            lst[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            lst[k] = right_half[j]
            j += 1
            k += 1

# Input list
unsorted_list = [36, 29, 12, 2, 9]
print("Unsorted list:",unsorted_list)

# Call the merge_sort function to sort the list
merge_sort(unsorted_list)

# Display the sorted list
print("Sorted list:", unsorted_list)
# Out:
# Unsorted list: [36, 29, 12, 2, 9]
# Sorted list: [2, 9, 12, 29, 36]

# %% [markdown]
# # 6. Write a Python script to perform the following operations on a singly linked list
# a. Create a list
# b. Find the smallest element from the list
# c. Insert an element if it is not a duplicate element
# d. Display the elements in reverse order

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def find_smallest(self):
        if not self.head:
            return None
        current = self.head
        smallest = current.data
        while current:
            if current.data < smallest:
                smallest = current.data
            current = current.next
        return smallest

    def insert_if_not_duplicate(self, data):
        if not self.head:
            self.head = Node(data)
        else:
            current = self.head
            while current:
                if current.data == data:
                    return  # Element is already in the list, don't insert
                if current.next is None:
                    current.next = Node(data)
                    return
                current = current.next

    def display_reverse(self):
        def _display_reverse(node):
            if node is None:
                return
            _display_reverse(node.next)
            print(node.data, end=" ")

        _display_reverse(self.head)

# Create an empty singly linked list
linked_list = SinglyLinkedList()

# Get user input for list creation
n = int(input("Enter the number of elements in the list: "))
print("Enter the elements into list:")
for i in range(n):
    element = int(input())
    linked_list.append(element)

# Find the smallest element
smallest_element = linked_list.find_smallest()
print(f"Smallest element: {smallest_element}")

# Get user input for element insertion
element_to_insert = int(input("Enter an element to insert if it's not a duplicate: "))
linked_list.insert_if_not_duplicate(element_to_insert)

# Display elements in reverse order
print("Elements in reverse order:")
linked_list.display_reverse()
# Out:
# Enter the number of elements in the list: 3
# Enter the elements into list:
# 4
# 7
# 2
# Smallest element: 2
# Enter an element to insert if it's not a duplicate: 6
# Elements in reverse order:
# 6 2 7 4

# %% [markdown]
# # 7. Write a python program to implement the various operations for Stack ADT
# i.)Push ii.)Pop iii.)Display.

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            print("Stack is empty. Cannot pop an item.")

    def is_empty(self):
        return len(self.items) == 0

    def display(self):
        if not self.is_empty():
            print("Stack contents:")
            for item in self.items[::-1]:
                print(item)
        else:
            print("Stack is empty.")

# Create a stack
stack = Stack()

while True:
    print("\nStack Operations:")
    print("1. Push")
    print("2. Pop")
    print("3. Display")
    print("4. Quit")

    choice = input("Enter your choice: ")

    if choice == '1':
        item = input("Enter an item to push onto the stack: ")
        stack.push(item)
        print(f"{item} pushed onto the stack.")
    elif choice == '2':
        popped_item = stack.pop()
        if popped_item is not None:
            print(f"Popped item: {popped_item}")
    elif choice == '3':
        stack.display()
    elif choice == '4':
        print("your choose quit")
        break
    else:
        print("Invalid choice. Please enter a valid option.")
# Out:
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice: 1
# Enter an item to push onto the stack: 3
# 3 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice: 1
# Enter an item to push onto the stack: 4
# 4 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice: 2
# Popped item: 4
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice: 3
# Stack contents:
# 3
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice: 4
# your choose quit

# %% [markdown]
# # 8. Write a python script to implement the various operations for Queue ADT
# i.)Insert ii.)Delete iii.)Display.

# %%
class Queue:
    def __init__(self):
        self.items = []

    def insert(self, item):
        self.items.append(item)

    def delete(self):
        if not self.is_empty():
            return self.items.pop(0)
        else:
            print("Queue is empty. Cannot delete an item.")

    def is_empty(self):
        return len(self.items) == 0

    def display(self):
        if not self.is_empty():
            print("Queue contents:")
            for item in self.items:
                print(item)
        else:
            print("Queue is empty.")

# Create a queue
queue = Queue()

while True:
    print("\nQueue Operations:")
    print("1. Insert (Enqueue)")
    print("2. Delete (Dequeue)")
    print("3. Display")
    print("4. Quit")

    choice = input("Enter your choice: ")

    if choice == '1':
        item = input("Enter an item to insert into the queue: ")
        queue.insert(item)
        print(f"{item} inserted into the queue.")
    elif choice == '2':
        deleted_item = queue.delete()
        if deleted_item is not None:
            print(f"Deleted item: {deleted_item}")
    elif choice == '3':
        queue.display()
    elif choice == '4':
        print("You choose quit")
        break
    else:
        print("Invalid choice. Please enter a valid option.")
# Out:
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter your choice: 1
# Enter an item to insert into the queue: 3
# 3 inserted into the queue.
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter your choice: 1
# Enter an item to insert into the queue: 9
# 9 inserted into the queue.
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter your choice: 3
# Queue contents:
# 3
# 9
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter your choice: 2
# Deleted item: 3
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter your choice: 3
# Queue contents:
# 9
#
# Queue Operations:
# 1. Insert (Enqueue)
# 2. Delete (Dequeue)
# 3. Display
# 4. Quit
# Enter your choice: 4
# You choose quit

# %% [markdown]
# # 9. Write a program in python to convert the following infix expression to its postfix form using push and pop operations of a Stack
# a. A/B^C+D*E-F*G
# b. (B^2-4*A*C)^(1/2)(100)

# %%
def infix_to_postfix(expression):
    precedence = {'+': 1, '-': 1, '*': 2, '/': 2, '^': 3}
    stack = []
    postfix = []
    
    for char in expression:
        if char.isalnum():
            postfix.append(char)
        elif char == '(':
            stack.append(char)
        elif char == ')':
            while stack and stack[-1] != '(':
                postfix.append(stack.pop())
            stack.pop()  # Remove the '(' from the stack
        else:
            while stack and precedence.get(stack[-1], 0) >= precedence.get(char, 0):
                postfix.append(stack.pop())
            stack.append(char)
    
    while stack:
        postfix.append(stack.pop())
    
    return ''.join(postfix)

# Example 1
infix_expr1 = "A/B^C+D*E-F*G"
postfix_expr1 = infix_to_postfix(infix_expr1)
print(f"Infix Expression 1: {infix_expr1}")
print(f"Postfix Expression 1: {postfix_expr1}")

# Example 2
infix_expr2 = "(B^2-4*A*C)^(1/2)(100)"
postfix_expr2 = infix_to_postfix(infix_expr2)
print(f"\nInfix Expression 2: {infix_expr2}")
print(f"Postfix Expression 2: {postfix_expr2}")
# Out:
# Infix Expression 1: A/B^C+D*E-F*G
# Postfix Expression 1: ABC^/DE*+FG*-
#
# Infix Expression 2: (B^2-4*A*C)^(1/2)(100)
# Postfix Expression 2: B2^4A*C*-12/100^
